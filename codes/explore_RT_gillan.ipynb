# %% [markdown]
# # Gillan human dataset RT exploration
#
# Source: Gillan et al. 2016, "Characterizing a Psychiatric symptom Dimension Related to Deficits in Goal-Directed Control", eLife, 2016;5:e11305"
#
# The notebook explores RT patterns to the dataset.

# %%
# %load_ext autoreload
# %autoreload 2
from datasets.GillanHumanDataset import GillanHumanDataset
from utils import goto_root_dir
from path_settings import *
import re
import numpy as np

# %%
import os
os.getcwd()
study = 1
data_directory = DATA_PATH / f"Gillandata/Experiment 1/twostep_data_study{study}"
all_names = os.listdir(data_directory)
pattern = re.compile(r'.*\.csv')
filtered = list(filter(lambda x: pattern.match(x), all_names))

# %%
# gillan_datasets = [GillanHumanDataset(data_path = DATA_PATH / f"Gillandata/Experiment 1/twostep_data_study{study}/{file_name}", behav_data_spec={}) for file_name in filtered]

gillan_dataset = GillanHumanDataset(data_path = DATA_PATH / f"Gillandata", behav_data_spec={})
# Out:
# ===loaded all=== Gillan Human
# Total batch size: 1961
# Total trial num: 392200

# %%
gillan_dataset.behav.keys()
# Out:
# dict_keys(['sub_id', 'drift_1', 'drift_2', 'drift_3', 'drift_4', 'stage_1_selected_stimulus', 'stage_1_RT', 'transition', 'stage_2_selected_stimulus', 'stage_2_state', 'stage_2_RT', 'reward', 'stage_1_selected_stimulus_mask', 'transition_mask', 'stage_2_state_mask', 'stage_2_selected_stimulus_mask', 'reward_mask', 'action', 'aug_block_number', 'trial_type'])

# %%
# Now seems to have loaded RT within the dataset. Let's see if there are weird RTs. 
for i, data in enumerate(gillan_dataset.behav['stage_2_RT']): 
    data_i = np.array(data) 
    if np.any(data_i < 0): 
        print(f"Found negative RTs in {i}")
        print(f"Negative RTs: {[j if data_i[j] < 0 else "" for j in range(len(data_i))]}")
# Out:
# Found negative RTs in 2
# Negative RTs: ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 101, '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# Found negative RTs in 3
# ...

# %%
# explore RT profiles
